# %% [markdown]
# # Watsapp Chat Analysis

# %%
fhand = open('PyET.txt',encoding = 'utf8')
for i in fhand: #for getting every line in file
    i=i.rstrip() #to remove the '\n' from each line
    print(i) #print all lines
# Out:
# 1/31/22, 15:49 - Messages and calls are end-to-end encrypted. No one outside of this chat, not even WhatsApp, can read or listen to them. Tap to learn more.
# 1/31/22, 15:42 - Anushya Mahe Praxis created group "PGPDS Jan'22 - BLR "
# 1/31/22, 15:49 - +91 98319 48077 added you
# 1/31/22, 15:52 - +91 70592 29103 joined using this group's invite link
# 1/31/22, 15:53 - Praxis Bhaskar joined using this group's invite link
# 1/31/22, 15:53 - +91 70592 29103 left
# 1/31/22, 15:53 - +91 96740 67641 joined using this group's invite link
# 1/31/22, 15:54 - +91 94836 22622 joined using this group's invite link
# 1/31/22, 15:55 - +91 97429 97747 joined using this group's invite link
# 1/31/22, 15:56 - +91 97906 93577 joined using this group's invite link
# 1/31/22, 15:56 - +91 6206 308 339 joined using this group's invite link
# 1/31/22, 15:56 - +91 98316 71628 joined using this group's invite link
# 1/31/22, 15:57 - +91 79905 19874 joined using this group's invite link
# ...

# %% [markdown]
# # Q1

# %%
fhand = open('PyET.txt',encoding = 'utf8')
members=[] #created a empty list for members name to be added
for i in fhand:
    i=i.rstrip() #to remove the '\n' from each line
    try:
        a=i[i.index('-')+2:i.index(':',16,55)]  #finding the '-' in every line because every member name start after 2 nd position after'-'
    except:
        continue    #index function gives an error when it does not find req string whereas find givesn-1 which makes substringing difficult
    if a not in members: #to avoid duplicate values
        members.append(a)  #appending members in list

# %%
members #showing us unique members who ever messaged in the group
# Out:
# ['Anushya Mahe Praxis',
#  'Praxis Madhuri Praxis Business School',
#  '+91 97736 87548',
#  '+91 6206 308 339',
#  '+91 75054 04417',
#  '+91 97906 93577',
#  '+91 88484 35019',
#  '+91 87575 13131',
#  '+91 98781 01877',
#  '+91 79905 19874',
#  '+91 98608 68194',
#  '+91 90796 99645',
#  '+91 94836 22622',
#  '+91 70342 08214',
#  '+91 99463 51164',
#  '+91 97411 21674',
#  '+91 95150 92417',
#  '+91 99788 89134',
#  '+91 98316 71628',
#  'Praveena Vinod',
#  '+91 97429 97747',
#  '+91 97269 95920',
#  '+91 95400 00588',
#  'Praxis Bhaskar',
#  '+91 96014 18197',
#  '+91 820 937 3714',
#  'Sushanta Praxis',
#  '+91 88600 61135',
#  '+91 96656 60920',
#  '+91 94447 66219',
#  'Praxis Aarti Madhavi',
#  '+91 99409 86538',
#  '+91 70301 03636',
#  '+91 94725 96200',
#  '+91 92233 84466',
#  '+91 79762 49627',
#  '+91 98319 48077',
#  'Teja Sai',
#  '+91 88846 30027',
#  '+91 97176 71005',
#  'Gourab Nath Praxis',
#  'Monali Sanjay Bendale']

# %% [markdown]
# # Q2

# %%
def conversation_by_date(file,date):
    
    fhand = open(file,encoding = 'utf8')
    for i in fhand:
        if int(date[3:5])<10 and int(date[:2])<10:   #main problem is date format dd/mm/yyyy whereas in chat it is mm/dd/yy
            if i.startswith(f'{date[4:5]}/{date[1:2]}/{date[8:]}'):
                print(i)
        elif int(date[3:5])>=10 and int(date[:2])<10:    #when date or month is less than 10 it gives 1 instead of 01 so we have to take various where date is single digit
            if i.startswith(f'{date[3:5]}/{date[1:2]}/{date[8:]}'):
                print(i)
        elif int(date[3:5])<10 and int(date[:2])>=10:
            if i.startswith(f'{date[4:5]}/{date[:2]}/{date[8:]}'):
                print(i)
        elif int(date[3:5])>=10 and int(date[:2])>=10:
            if i.startswith(f'{date[3:5]}/{date[:2]}/{date[8:]}'):
                print(i)

# %%
date='16/02/2022'
file='PyET.txt'
conversation_by_date(file,date) #printing whatsapp chats on 16/02/2022
# Out:
# 2/16/22, 10:47 - Praveena Vinod: Please do not join late for the classes
#
# 2/16/22, 10:47 - Praveena Vinod: faculty is waiting
#
# 2/16/22, 10:48 - Praveena Vinod: join for the class now
#
# 2/16/22, 13:25 - Praveena Vinod: 1.Bhaskar
#
# 2/16/22, 13:26 - Praveena Vinod: 1.Teja
#
# 2/16/22, 13:44 - +91 87575 13131: Done
#
# 2/16/22, 13:47 - +91 87575 13131: Done
#
# 2/16/22, 14:34 - +91 88600 61135: Hi All, Please fill this form for SQL as communicated by Saurabh sir in class.
#
# 2/16/22, 14:35 - +91 99463 51164: Should we give the praxis mail id or personal mail?
#
# 2/16/22, 14:35 - +91 75054 04417: Both
#
# 2/16/22, 14:35 - +91 88600 61135: Personal
#
# 2/16/22, 14:37 - +91 88600 61135: Wait let me re confirm
#
# 2/16/22, 14:37 - +91 75054 04417: 1st me official and 2nd me personal
#
# 2/16/22, 14:37 - +91 75054 04417: I think.
#
# 2/16/22, 14:47 - +91 88600 61135: Please do what Himkant has suggested
#
# 2/16/22, 14:47 - +91 99463 51164: Okey thanks 🤝
#
# ...

# %% [markdown]
# # Q3

# %%
def converstion_by_person(file,person):   
    fhand = open(file,encoding = 'utf8')
    member_chat={}
    for i in fhand:
        i=i.rstrip() #to remove the '\n' from each line
        try:
            a=i[i.index('-')+2:i.index(':',16,55)] #substringing done to extract name of person messaging 
            b=i[i.index('-')+2:] #extracting chat to that person in that line
        except:
            continue
        member_chat[a] = member_chat.get(a,'')+","+b #adding all chats with name in dictionary seprated by a comma
    return(member_chat[person])

# %%
converstion_by_person('PyET.txt','Gourab Nath Praxis')
# Out:
# Gourab Nath Praxis: Hi, everyone!
# Gourab Nath Praxis: Does this give you the chance start working with the IML assignment?
# Gourab Nath Praxis: Whichever team makes it todays gets 5 extra points...
# Gourab Nath Praxis: 👍🏼
# Gourab Nath Praxis: Whoever starts the project from the campus today gets the point...
# Gourab Nath Praxis: Btw 5 points in IML - no joke!!
# Gourab Nath Praxis: You can start as well
# Gourab Nath Praxis: Get the data from Savi
# Gourab Nath Praxis: Take a break for 10 mins. Will start at 11.

# %%
def converstion_by_person(file,person):   
    fhand = open(file,encoding = 'utf8')
    member_chat={}
    for i in fhand:
        i=i.rstrip() #to remove the '\n' from each line
        try:
            a=i[i.index('-')+2:i.index(':',16,55)] #substringing done to extract name of person messaging 
            b=i[i.index('-')+2:] #extracting chat to that person in that line
        except:
            continue
        if a==person:
            print(b)

# %% [markdown]
# # Q4

# %%
fhand = open('PyET.txt',encoding = 'utf8')
am=[] #created 2 empty lists am, pm 
pm=[]
for i in fhand:
    i=i.rstrip() #to remove the '\n' from each line
    try:
        if int(i[i.index(' ',0,10)+1:i.index(' ',0,10)+3])>11:   #differenciating msg based on time that they fall in am list or pm list
            pm.append(i[i.index(' ',0,10)+1:i.index(' ',0,10)+6])
        if int(i[i.index(' ',0,10)+1:i.index(' ',0,10)+3])<=11:
            am.append(i[i.index(' ',0,10)+1:i.index(' ',0,10)+6])
    except:
        a=1
len(am),len(pm)
# Out:
# (106, 413)

# %%
if len(am)>len(pm): #as pm has more chats so group has more msg freq in pm 
    print('messages are more in am')
if len(pm)>len(am):
    print('messages are more in pm')
# Out:
# messages are more in pm

# %% [markdown]
# # Q5

# %%
hour_freq={}
hours_frequency=am+pm
for i in hours_frequency:
    a=i[0:2]
    hour_freq[a] = hour_freq.get(a,0)+1 #creating dictionary for hourly number og msgs
hour_freq
# Out:
# {'02': 1,
#  '11': 15,
#  '08': 8,
#  '10': 69,
#  '09': 13,
#  '15': 84,
#  '16': 75,
#  '17': 48,
#  '18': 6,
#  '19': 3,
#  '23': 1,
#  '13': 36,
#  '12': 65,
#  '14': 85,
#  '20': 7,
#  '21': 2,
#  '22': 1}

# %% [markdown]
# ## Q6:

# %%
def avg_length_by_person(file,person):   
    fhand = open(file,encoding = 'utf8')
    member_chat={}
    member_count={}
    for i in fhand:
        i=i.rstrip() #to remove the '\n' from each line
        try:
            a=i[i.index('-')+2:i.index(':',16,55)]
            b=i[i.index(':',16,55)+2:]
        except:
            continue
        member_chat[a] = member_chat.get(a,0)+len(b) #similarly as in last question a dictionary is craeted but this time for length of string
        member_count[a] = member_count.get(a,0)+1 #new dictionary with count of messages done by single user
    member_avg_count=(member_chat[person]/member_count[person]) #finding avg by dividing len of chat by count of number of msgs tilldate sent by that person
    return(member_avg_count)

# %%
avg_length_by_person('PyET.txt','Gourab Nath Praxis')
# Out:
# 35.44444444444444
